# %% [markdown]
# # Recommender Systems by StreamHopper
# ## Item Similarity Search

# %%
from similarity import *

# %%
data_path = Path('/Users/alaa/data/stream-hopper/imdb_data_v2/')

# %%
starter_df = pd.read_csv(data_path/'starter_items_v2.csv')

# %% [markdown]
# ### TV

# %%
# guidebox data
gb_df = pd.read_csv(data_path/'tv.csv')
meta_df = pd.read_csv(data_path/'tv-meta.csv')
plots_df = pd.read_csv(data_path/'tv-text.csv')
imgs_df = pd.read_csv(data_path/'tv-imgs.csv')
meta_df = load_plot_metadata(meta_df, plots_df)
merged_df = gb_df.merge(meta_df, how='inner', on='imdb_id')

# %%
starter_meta_df = get_starter_metadata(starter_df, 'tv')
# Out:
# 100%|██████████| 5/5 [00:13<00:00,  2.72s/it]
# 100%|██████████| 5/5 [00:18<00:00,  3.77s/it]
# 100%|██████████| 5/5 [00:18<00:00,  3.66s/it]
# 100%|██████████| 5/5 [00:13<00:00,  2.62s/it]
# 100%|██████████| 5/5 [00:14<00:00,  2.93s/it]
# 100%|██████████| 5/5 [00:16<00:00,  3.25s/it]
# 100%|██████████| 5/5 [00:13<00:00,  2.73s/it]
# 100%|██████████| 5/5 [00:13<00:00,  2.72s/it]
# 100%|██████████| 5/5 [00:15<00:00,  3.17s/it]
# 100%|██████████| 5/5 [00:18<00:00,  3.63s/it]

# %%
x_df = compute_similarity_scores(starter_meta_df, merged_df, imgs_df, 'tv')

# %%
x_df['avg_score'] = x_df[['rating_score', 'votes_score',
                          'cast_score', 'writers_score', 'producers_score', 
                          'plot_score']].mean(axis=1)

# %%
starter_df[[f'show{i}' for i in [1,2,3,4,5]]]
# Out:
#               show1            show2            show3             show4  \
# 0        The Office  Game of Thrones         New Girl  Sex and the City
# 1        The Office         New Girl   Silicon Valley              Lost
# 2        The Office     Breaking Bad       This Is Us   Game of Thrones
# 3      Breaking Bad       The Office            Arrow              Lost
# 4   Game of Thrones   Silicon Valley     Breaking Bad             Arrow
# 5   Game of Thrones            Arrow       The Office        This Is Us
# 6   Game of Thrones       The Office        The Crown       The Witcher
# 7  Sex and the City       This Is Us  Game of Thrones            Archer
# 8   Game of Thrones     Breaking Bad       The Office    Rick and Morty
# 9      The Simpsons  Game of Thrones           Archer         Entourage
#
#                                show5
# 0                     Rick and Morty
# 1                    Game of Thrones
# 2                               Lost
# 3  It's Always Sunny in Philadelphia
# 4                          Entourage
# 5                      Downton Abbey
# 6                           New Girl
# 7                          The Crown
# 8                              Arrow
# 9                       Breaking Bad

# %%
get_recommendations_per_show(x_df, "Lost")
# Out:
#         persona  starter_id starter_title  other_id  \
# 110875        1    285403.0          Lost  411008.0
# 400           1    413573.0          Lost  411008.0
# 925           1    452046.0          Lost  411008.0
# 64075         1    312172.0          Lost  411008.0
# 112625        1    410975.0          Lost  411008.0
# 4375          1   3322312.0          Lost  411008.0
# 170875        1    475784.0          Lost  411008.0
# 325           1    903747.0          Lost  411008.0
# 5125          1   1839578.0          Lost  411008.0
# 4875          1   5675620.0          Lost  411008.0
# 111750        1   2699128.0          Lost  411008.0
# 170925        1    944947.0          Lost  411008.0
# 118525        1    758737.0          Lost  411008.0
# 275           1   1520211.0          Lost  411008.0
# 117725        1    805669.0          Lost  411008.0
# 62525   https://m.media-amazon.com/images/M/MV5BMDA4Nj...   0.310393
# 110325  https://m.media-amazon.com/images/M/MV5BMjRiND...   0.308414
# 110025  https://m.media-amazon.com/images/M/MV5BMmUyNT...   0.308206
# 164025  https://m.media-amazon.com/images/M/MV5BMzk0Mz...   0.307384
# 113475  https://m.media-amazon.com/images/M/MV5BOTcwNz...   0.306331
# 2375    https://m.media-amazon.com/images/M/MV5BMTM5Mj...   0.306208
# 163875  https://m.media-amazon.com/images/M/MV5BMTkyMj...   0.305935
# 62050   https://m.media-amazon.com/images/M/MV5BZGJjYz...   0.305090
# 61900   https://m.media-amazon.com/images/M/MV5BZmY5ZD...   0.304005
# 130175  https://m.media-amazon.com/images/M/MV5BMTFhOW...   0.303903
# 8425    https://m.media-amazon.com/images/M/MV5BMTUxNz...   0.302236
# 109725  https://m.media-amazon.com/images/M/MV5BNTUyYj...   0.301968
# 62575   https://m.media-amazon.com/images/M/MV5BMzgxMm...   0.301794
# 3550    https://m.media-amazon.com/images/M/MV5BNTFlYT...   0.301596
# 49075   https://m.media-amazon.com/images/M/MV5BNWU4Nm...   0.301268
# 8500    https://m.media-amazon.com/images/M/MV5BODkzMj...   0.300602
# 3825    https://m.media-amazon.com/images/M/MV5BODM1MD...   0.300489
# 2975    https://m.media-amazon.com/images/M/MV5BZTdkMG...   0.300453
# 475     https://m.media-amazon.com/images/M/MV5BMDNkOT...   0.300318
# 61800   https://m.media-amazon.com/images/M/MV5BNjIzZj...   0.300276
# 113025  https://m.media-amazon.com/images/M/MV5BMTIwMD...   0.299421

# %%
starter_df[[f'show{i}' for i in [1,2,3,4,5]]]
# Out:
#               show1            show2            show3             show4  \
# 0        The Office  Game of Thrones         New Girl  Sex and the City
# 1        The Office         New Girl   Silicon Valley              Lost
# 2        The Office     Breaking Bad       This Is Us   Game of Thrones
# 3      Breaking Bad       The Office            Arrow              Lost
# 4   Game of Thrones   Silicon Valley     Breaking Bad             Arrow
# 5   Game of Thrones            Arrow       The Office        This Is Us
# 6   Game of Thrones       The Office        The Crown       The Witcher
# 7  Sex and the City       This Is Us  Game of Thrones            Archer
# 8   Game of Thrones     Breaking Bad       The Office    Rick and Morty
# 9      The Simpsons  Game of Thrones           Archer         Entourage
#
#                                show5
# 0                     Rick and Morty
# 1                    Game of Thrones
# 2                               Lost
# 3  It's Always Sunny in Philadelphia
# 4                          Entourage
# 5                      Downton Abbey
# 6                           New Girl
# 7                          The Crown
# 8                              Arrow
# 9                       Breaking Bad

# %%
persona = ['The Office', 'This Is Us', 'New Girl',
         'Arrow', 'Breaking Bad']
get_recommendations_per_persona(x_df, persona)
# Out:
#                  other_title           mod       avg
# 1                  The Flash       netflix  0.334749
# 2            Game of Thrones       hbo_now  0.324827
# 3       Arrested Development       netflix  0.319595
# 4               The Simpsons     hulu_plus  0.319420
# 5                    Firefly     hulu_plus  0.318530
# 6       Parks and Recreation       netflix  0.314593
# 7              Modern Family     hulu_plus  0.314383
# 8      How I Met Your Mother     hulu_plus  0.314197
# 9                   Sherlock       netflix  0.313565
# 10              Prison Break     hulu_plus  0.312597
# 11                 Chernobyl       hbo_now  0.311477
# 12          The Walking Dead       netflix  0.310636
# 13                     House  amazon_prime  0.310497
# 14                 Westworld       hbo_now  0.308927
# 15                  The Wire  amazon_prime  0.308530
# 16                Family Guy     hulu_plus  0.307652
# 17           Stranger Things       netflix  0.307242
# 18              Supernatural       netflix  0.307011
# 19          Band of Brothers  amazon_prime  0.306972
# 20               The X-Files     hulu_plus  0.306458
# 21                The Shield     hulu_plus  0.305483
# 22            True Detective       hbo_now  0.304818
# 23                  Futurama     hulu_plus  0.304761
# 24              The Sopranos  amazon_prime  0.304276
# 25            Rick and Morty     hulu_plus  0.304247
# 26  DC's Legends of Tomorrow       netflix  0.304196
# 27     American Horror Story       netflix  0.303395
# 28                   Lucifer       netflix  0.302670
# 29                    Dexter       netflix  0.302412
# 30              Black Mirror       netflix  0.301988
# 31                 Shameless       netflix  0.301543
# 32                        24     hulu_plus  0.301173
# 33                     Fargo     hulu_plus  0.300780
# 34            House of Cards       netflix  0.300702
# 35                   Mad Men       netflix  0.300218
# 36            That '70s Show       netflix  0.299750
# 37                    Narcos       netflix  0.299401
# 38     Malcolm in the Middle     hulu_plus  0.298864
# 39                 Community       netflix  0.298390
# 40                Death Note       netflix  0.297569
# 41                 Daredevil       netflix  0.297239
# 42                      Lost     hulu_plus  0.296886
# 43                   Vikings  amazon_prime  0.296756
# 44            Peaky Blinders       netflix  0.296324
# 45        Person of Interest       netflix  0.296053
# 46        Brooklyn Nine-Nine     hulu_plus  0.295711
# 47                South Park     hulu_plus  0.295560
# 48                     Suits  amazon_prime  0.295497
# 49  Buffy the Vampire Slayer     hulu_plus  0.295304

# %% [markdown]
# ### MOVIES

# %%
# guidebox data
gb_df = pd.read_csv(data_path/'movies.csv')

# %%
meta_df = pd.read_csv(data_path/'movies-meta.csv')

# %%
plots_df = pd.read_csv(data_path/'movies-text.csv')

# %%
meta_df = load_plot_metadata(meta_df, plots_df)

# %%
merged_df = gb_df.merge(meta_df, how='inner', on='imdb_id')

# %%
starter_meta_df = get_starter_metadata(starter_df)
# Out:
# 100%|██████████| 5/5 [00:15<00:00,  3.00s/it]
#  40%|████      | 2/5 [00:06<00:10,  3.44s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-3e4b23ee5038> in <module>
# ----> 1 starter_meta_df = get_starter_metadata(starter_df)
#
# ~/git/2020-product-analytics-group-project-group1/model/tashaboh/similarity.py in get_starter_metadata(starter_items)
#     111     for persona, starter_ids in starter_items.iterrows():
#     112         starter_ids = starter_ids[[f'show_id{i}' for i in [1,2,3,4,5]]].values.tolist()
# --> 113         starter_meta_info = acquire_imdb_data(starter_ids)
#     114         starter_meta_df = collect_metadata(starter_meta_info, 'tv')
#     115         starter_meta_df['persona'] = persona
#
# ~/git/2020-product-analytics-group-project-group1/api/imdb_query.py in acquire_imdb_data(imdb_ids)
#      44         for i, show_id in enumerate(imdb_ids):
#      45             show_id = int(show_id)
# ---> 46             show = ia.get_movie(show_id)
#      47             show_id = show.getID()
#      48             show_items = show.items()
#
# ~/git/2020-product-analytics-group-project-group1/stream-hopper/lib/python3.7/site-packages/imdb/__init__.py in get_movie(self, movieID, info, modFunct)
#     402         if modFunct is not None:
#     403             movie.set_mod_funct(modFunct)
# --> 404         self.update(movie, info)
#     405         return movie
#     406
#
# ~/git/2020-product-analytics-group-project-group1/stream-hopper/lib/python3.7/site-packages/imdb/__init__.py in update(self, mop, info, override)
#     730                 method = lambda *x: {}
#     731             try:
# --> 732                 ret = method(mopID)
#     733             except Exception:
#     734                 _imdb_logger.critical(
#
# ~/git/2020-product-analytics-group-project-group1/stream-hopper/lib/python3.7/site-packages/imdb/parser/http/__init__.py in get_movie_main(self, movieID)
#     437
#     438     def get_movie_main(self, movieID):
# --> 439         cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#     440         return self.mProxy.movie_parser.parse(cont, mdparse=self._mdparse)
#     441
#
# ~/git/2020-product-analytics-group-project-group1/stream-hopper/lib/python3.7/site-packages/imdb/parser/http/__init__.py in _retrieve(self, url, size, _noCookies)
#     374         """Retrieve the given URL."""
#     375         self._http_logger.debug('fetching url %s (size: %d)', url, size)
# --> 376         ret = self.urlOpener.retrieve_unicode(url, size=size)
#     377         if PY2 and isinstance(ret, str):
#     378             ret = ret.decode('utf-8')
#
# ~/git/2020-product-analytics-group-project-group1/stream-hopper/lib/python3.7/site-packages/imdb/parser/http/__init__.py in retrieve_unicode(self, url, size)
#     217             uopener = build_opener(*handlers)
#     218             uopener.addheaders = list(self.addheaders)
# --> 219             response = uopener.open(url)
#     220             content = response.read()
#     221             self._last_url = response.url
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
# -> 1320             r = h.getresponse()
#    1321         except:
#    1322             h.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
imgs_df = pd.read_csv("/Users/alaa/data/stream-hopper/imdb_data_v2/movie-imgs.csv")

# %%
x_df = compute_similarity_scores(starter_meta_df, merged_df, imgs_df, 'tv')

# %%
x_df['avg_score'] = x_df[['rating_score', 'votes_score',
                          'cast_score', 'writers_score', 'producers_score', 
                          'plot_score']].mean(axis=1)

# %%
starter_df[[f'show{i}' for i in [1,2,3,4,5]]]
# Out:
#               show1            show2            show3             show4  \
# 0        The Office  Game of Thrones         New Girl  Sex and the City
# 1        The Office         New Girl   Silicon Valley              Lost
# 2        The Office     Breaking Bad       This Is Us   Game of Thrones
# 3      Breaking Bad       The Office            Arrow              Lost
# 4   Game of Thrones   Silicon Valley     Breaking Bad             Arrow
# 5   Game of Thrones            Arrow       The Office        This Is Us
# 6   Game of Thrones       The Office        The Crown       The Witcher
# 7  Sex and the City       This Is Us  Game of Thrones            Archer
# 8   Game of Thrones     Breaking Bad       The Office    Rick and Morty
# 9      The Simpsons  Game of Thrones           Archer         Entourage
# 0        The Office  Game of Thrones         New Girl  Sex and the City
# 1        The Office         New Girl   Silicon Valley              Lost
# 2        The Office     Breaking Bad       This Is Us   Game of Thrones
# 3      Breaking Bad       The Office            Arrow              Lost
# 4   Game of Thrones   Silicon Valley     Breaking Bad             Arrow
# 5   Game of Thrones            Arrow       The Office        This Is Us
# 6   Game of Thrones       The Office        The Crown       The Witcher
# 7  Sex and the City       This Is Us  Game of Thrones            Archer
# 8   Game of Thrones     Breaking Bad       The Office    Rick and Morty
# 9      The Simpsons  Game of Thrones           Archer         Entourage
#
#                                show5
# 0                     Rick and Morty
# 1                    Game of Thrones
# 2                               Lost
# 3  It's Always Sunny in Philadelphia
# 4                          Entourage
# 5                      Downton Abbey
# 6                           New Girl
# 7                          The Crown
# 8                              Arrow
# 9                       Breaking Bad

# %%
# persona = ['The Office', 'This Is Us', 'New Girl',
#          'Arrow', 'Breaking Bad']
# get_recommendations_per_persona(x_df, shows)
# Out:
#                  other_title           mod       avg
# 1                  The Flash       netflix  0.345981
# 2            Game of Thrones       hbo_now  0.337916
# 3       Arrested Development       netflix  0.332833
# 4               The Simpsons     hulu_plus  0.332817
# 5                    Firefly     hulu_plus  0.332125
# 6      How I Met Your Mother     hulu_plus  0.327575
# 7              Modern Family     hulu_plus  0.327486
# 8                   Sherlock       netflix  0.326034
# 9       Parks and Recreation       netflix  0.326013
# 10              Prison Break     hulu_plus  0.325944
# 11                 Chernobyl       hbo_now  0.323962
# 12          The Walking Dead       netflix  0.322368
# 13                     House  amazon_prime  0.322344
# 14                 Westworld       hbo_now  0.320610
# 15                  The Wire  amazon_prime  0.320577
# 16                Family Guy     hulu_plus  0.320219
# 17               The X-Files     hulu_plus  0.319530
# 18           Stranger Things       netflix  0.319436
# 19          Band of Brothers  amazon_prime  0.319157
# 20              Supernatural       netflix  0.318680
# 21                The Shield     hulu_plus  0.318160
# 22                  Futurama     hulu_plus  0.317764
# 23            True Detective       hbo_now  0.317032
# 24            Rick and Morty     hulu_plus  0.316327
# 25     American Horror Story       netflix  0.316319
# 26              The Sopranos  amazon_prime  0.316265
# 27                    Dexter       netflix  0.314415
# 28                        24     hulu_plus  0.314298
# 29  DC's Legends of Tomorrow       netflix  0.314039
# 30                   Lucifer       netflix  0.313894
# 31              Black Mirror       netflix  0.313894
# 32                 Shameless       netflix  0.312969
# 33            House of Cards       netflix  0.312660
# 34                     Fargo     hulu_plus  0.312641
# 35            That '70s Show       netflix  0.312100
# 36                   Mad Men       netflix  0.311667
# 37     Malcolm in the Middle     hulu_plus  0.311367
# 38                    Narcos       netflix  0.311292
# 39                 Community       netflix  0.309725
# 40                Death Note       netflix  0.309297
# 41                 Daredevil       netflix  0.308945
# 42                   Vikings  amazon_prime  0.308733
# 43                      Lost     hulu_plus  0.308551
# 44            Peaky Blinders       netflix  0.308071
# 45  Buffy the Vampire Slayer     hulu_plus  0.307925
# 46                South Park     hulu_plus  0.307318
# 47        Person of Interest       netflix  0.307308
# 48                     Suits  amazon_prime  0.307154
# 49        Brooklyn Nine-Nine     hulu_plus  0.307006
